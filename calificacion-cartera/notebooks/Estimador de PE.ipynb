# %% [markdown]
# # MORA12, SALPRES, VEA y SINMORA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Cargar todos los archivos que están en la carpeta /Archivos originales/CARTERA y ponerle al dataframe el mismo nombre que el archivo
carpeta_path = 'C:\\Users\\jhquiza\\OneDrive - Universidad de Medellin\\2025-2\\Proyecto riesgos\\Archivos septiembre 2025\\ARCHIVOS CRÉDITO'
archivos = os.listdir(carpeta_path)
dataframes = {}
for archivo in archivos:
    if archivo.endswith('.xlsx'):
        nombre_df = archivo.split('.')[0]
        nombre_df = nombre_df.split('_', maxsplit=1)[1]
        ruta_archivo = os.path.join(carpeta_path, archivo)
        dataframes[nombre_df] = pd.read_excel(ruta_archivo, header=3)
        print(f'Archivo {archivo} cargado como DataFrame {nombre_df}')
# Out:
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_ABRIL_2025.xlsx cargado como DataFrame ABRIL_2025
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_AGOSTO_2025.xlsx cargado como DataFrame AGOSTO_2025
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_DICIEMBRE_2024.xlsx cargado como DataFrame DICIEMBRE_2024
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_ENERO_2025.xlsx cargado como DataFrame ENERO_2025
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_FEBRERO_2025.xlsx cargado como DataFrame FEBRERO_2025
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_JULIO_2025.xlsx cargado como DataFrame JULIO_2025
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_JUNIO_2025.xlsx cargado como DataFrame JUNIO_2025
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_MARZO_2025.xlsx cargado como DataFrame MARZO_2025
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_MAYO_2025.xlsx cargado como DataFrame MAYO_2025
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_NOVIEMBRE_2024.xlsx cargado como DataFrame NOVIEMBRE_2024
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_OCTUBRE_2024.xlsx cargado como DataFrame OCTUBRE_2024
# Archivo INFORME INDIVIDUAL DE CARTERA DE CREDITO (MODIFICADO)_SEPTIEMBRE_2025.xlsx cargado como DataFrame SEPTIEMBRE_2025

# %%
# Preservar en cada dataframe solo las columnas "NIT", "NroCredito", "CodigoContable" y "Morosidad"
for nombre_df in dataframes.keys():
    dataframes[nombre_df] = dataframes[nombre_df][['NIT', 'NroCredito', 'CodigoContable', 'Morosidad','ValorPrestamo', 'SaldoCapital', 'SaldoIntereses', 'OtrosSaldos', 'clasegarantia']]
    dataframes[nombre_df] = dataframes[nombre_df].dropna(subset=['NroCredito'])
    dataframes[nombre_df] = dataframes[nombre_df].drop_duplicates(subset=['NroCredito'])
    dataframes[nombre_df] = dataframes[nombre_df].set_index('NroCredito')
    dataframes[nombre_df]['SALPRES'] = dataframes[nombre_df]['SaldoCapital']/dataframes[nombre_df]['ValorPrestamo']
    dataframes[nombre_df]['VEA'] = dataframes[nombre_df]['SaldoCapital']+dataframes[nombre_df]['SaldoIntereses']+dataframes[nombre_df]['OtrosSaldos']

# Hacer una lista con las keys de los dataframes ordenadas cronológicamente de forma automática
meses_es = {
	'ENERO': 1, 'FEBRERO': 2, 'MARZO': 3, 'ABRIL': 4, 'MAYO': 5, 'JUNIO': 6,
	'JULIO': 7, 'AGOSTO': 8, 'SEPTIEMBRE': 9, 'OCTUBRE': 10, 'NOVIEMBRE': 11, 'DICIEMBRE': 12
}

def mes_ano_to_date(mes_ano):
	mes, ano = mes_ano.split('_')
	return pd.Timestamp(year=int(ano), month=meses_es[mes], day=1)

meses_ordenados = sorted(dataframes.keys(), key=mes_ano_to_date)
meses_ordenados
# Out:
# ['OCTUBRE_2024',
#  'NOVIEMBRE_2024',
#  'DICIEMBRE_2024',
#  'ENERO_2025',
#  'FEBRERO_2025',
#  'MARZO_2025',
#  'ABRIL_2025',
#  'MAYO_2025',
#  'JUNIO_2025',
#  'JULIO_2025',
#  'AGOSTO_2025',
#  'SEPTIEMBRE_2025']

# %%
# Fusionar todos los dataframes en uno solo, usando como clave primaria el índice, usando la función merge el método outer, y nombrando cada columna nueva con el nombre del dataframe original
df_mora = dataframes[meses_ordenados[0]][['NIT', 'Morosidad', 'CodigoContable', 'SALPRES', 'VEA']].copy()
df_mora = df_mora.rename(columns={'Morosidad': f'Morosidad_{meses_ordenados[0]}', 
                                  'CodigoContable': f'CodigoContable_{meses_ordenados[0]}', 
                                  'NIT': f'NIT_{meses_ordenados[0]}',
                                  'SALPRES': f'SALPRES_{meses_ordenados[0]}',
                                  'VEA': f'VEA_{meses_ordenados[0]}',
                                  'clasegarantia': f'clasegarantia_{meses_ordenados[0]}'}
                                  )

for mes in meses_ordenados[1:]:
    df_temp = dataframes[mes][['NIT', 'Morosidad', 'CodigoContable', 'SALPRES', 'VEA', 'clasegarantia']].copy()
    df_temp = df_temp.rename(columns={'Morosidad': f'Morosidad_{mes}', 
                                      'CodigoContable': f'CodigoContable_{mes}', 
                                      'NIT': f'NIT_{mes}',
                                      'SALPRES': f'SALPRES_{mes}',
                                      'VEA': f'VEA_{mes}',
                                      'clasegarantia': f'clasegarantia_{mes}'}
                                      )
    
    df_mora = df_mora.merge(df_temp, left_index=True, right_index=True, how='outer') 
df_mora
# Out:
#                   NIT_OCTUBRE_2024  Morosidad_OCTUBRE_2024  \
# NroCredito
# 7                       1040039171                     0.0
# 9                              NaN                     NaN
# 17                      1036670861                     0.0
# 20                             NaN                     NaN
# 21                             NaN                     NaN
# ...                            ...                     ...
# 007-002-0001463-2              NaN                     NaN
# 007-002-0001464-1              NaN                     NaN
# 007-002-0001467-8              NaN                     NaN
# 007-002-0001468-7              NaN                     NaN
# 007-002-0001472-1              NaN                     NaN
#
#                    CodigoContable_OCTUBRE_2024  SALPRES_OCTUBRE_2024  \
# NroCredito
# 7                                     146905.0              0.970262
# 9                                          NaN                   NaN
# 17                                    146930.0              0.972392
# 20                                         NaN                   NaN
# 21                                         NaN                   NaN
# ...                                        ...                   ...
# 007-002-0001463-2                          NaN                   NaN
# 007-002-0001464-1                          NaN                   NaN
# 007-002-0001467-8                          NaN                   NaN
# 007-002-0001468-7                          NaN                   NaN
# 007-002-0001472-1                          NaN                   NaN
#
#                    VEA_OCTUBRE_2024 NIT_NOVIEMBRE_2024  \
# NroCredito
# 7                        77620954.0         1040039171
# 9                               NaN                NaN
# 17                        6517916.0         1036670861
# 20                              NaN                NaN
# 21                              NaN                NaN
# ...                             ...                ...
# 007-002-0001463-2               NaN                NaN
# 007-002-0001464-1               NaN                NaN
# 007-002-0001467-8               NaN                NaN
# 007-002-0001468-7               NaN                NaN
# 007-002-0001472-1               NaN                NaN
#
#                    Morosidad_NOVIEMBRE_2024  CodigoContable_NOVIEMBRE_2024  \
# NroCredito
# 7                                       0.0                       146905.0
# 9                                       NaN                            NaN
# 17                                      0.0                       146930.0
# 20                                      NaN                            NaN
# 21                                      NaN                            NaN
# ...                                     ...                            ...
# 007-002-0001463-2                       NaN                            NaN
# 007-002-0001464-1                       NaN                            NaN
# 007-002-0001467-8                       NaN                            NaN
# 007-002-0001468-7                       NaN                            NaN
# 007-002-0001472-1                       NaN                            NaN
#
#                    SALPRES_NOVIEMBRE_2024  VEA_NOVIEMBRE_2024  ...  \
# NroCredito                                                     ...
# 7                                0.955391          76431287.0  ...
# 9                                     NaN                 NaN  ...
# 17                               0.954423           6397474.0  ...
# 20                                    NaN                 NaN  ...
# 21                                    NaN                 NaN  ...
# ...                                   ...                 ...  ...
# 007-002-0001463-2                     NaN                 NaN  ...
# 007-002-0001464-1                     NaN                 NaN  ...
# 007-002-0001467-8                     NaN                 NaN  ...
# 007-002-0001468-7                     NaN                 NaN  ...
# 007-002-0001472-1                     NaN                 NaN  ...
#
#                    CodigoContable_AGOSTO_2025 SALPRES_AGOSTO_2025  \
# NroCredito
# 7                                         NaN                 NaN
# 9                                         NaN                 NaN
# 17                                        NaN                 NaN
# 20                                        NaN                 NaN
# 21                                        NaN                 NaN
# ...                                       ...                 ...
# 007-002-0001463-2                    144205.0            0.936706
# 007-002-0001464-1                    144205.0            0.400000
# 007-002-0001467-8                    144205.0            0.887833
# 007-002-0001468-7                    144205.0            0.940565
# 007-002-0001472-1                         NaN                 NaN
#
#                    VEA_AGOSTO_2025  clasegarantia_AGOSTO_2025  \
# NroCredito
# 7                              NaN                        NaN
# 9                              NaN                        NaN
# 17                             NaN                        NaN
# 20                             NaN                        NaN
# 21                             NaN                        NaN
# ...                            ...                        ...
# 007-002-0001463-2         966346.0                        1.0
# 007-002-0001464-1        4002147.0                        1.0
# 007-002-0001467-8        2701704.0                        1.0
# 007-002-0001468-7        4778096.0                        1.0
# 007-002-0001472-1              NaN                        NaN
#
#                    NIT_SEPTIEMBRE_2025  Morosidad_SEPTIEMBRE_2025  \
# NroCredito
# 7                                  NaN                        NaN
# 9                                  NaN                        NaN
# 17                                 NaN                        NaN
# 20                                 NaN                        NaN
# 21                                 NaN                        NaN
# ...                                ...                        ...
# 007-002-0001463-2           1035912774                       44.0
# 007-002-0001464-1             15437544                        0.0
# 007-002-0001467-8             43907525                        0.0
# 007-002-0001468-7           1036964056                       14.0
# 007-002-0001472-1           1001370322                        0.0
#
#                    CodigoContable_SEPTIEMBRE_2025 SALPRES_SEPTIEMBRE_2025  \
# NroCredito
# 7                                             NaN                     NaN
# 9                                             NaN                     NaN
# 17                                            NaN                     NaN
# 20                                            NaN                     NaN
# 21                                            NaN                     NaN
# ...                                           ...                     ...
# 007-002-0001463-2                        144210.0                0.936706
# 007-002-0001464-1                        144205.0                0.400000
# 007-002-0001467-8                        144205.0                0.880690
# 007-002-0001468-7                        144205.0                0.940565
# 007-002-0001472-1                        144205.0                0.623300
#
#                    VEA_SEPTIEMBRE_2025  clasegarantia_SEPTIEMBRE_2025
# NroCredito
# 7                                  NaN                            NaN
# 9                                  NaN                            NaN
# 17                                 NaN                            NaN
# 20                                 NaN                            NaN
# 21                                 NaN                            NaN
# ...                                ...                            ...
# 007-002-0001463-2             980626.0                            1.0
# 007-002-0001464-1            4066557.0                            1.0
# 007-002-0001467-8            2684521.0                            1.0
# 007-002-0001468-7            4851986.0                            1.0
# 007-002-0001472-1            1871907.0                            1.0
#
# [30748 rows x 71 columns]

# %%
# Se eliminan todos los registros que no tienen NIT en el último mes, para que solo queden los créditos vigentes al último mes de los datos

last_month = meses_ordenados[-1]
df_mora = df_mora.dropna(subset=[f'NIT_{last_month}'])
df_mora.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21020 entries, 002-001-0000024-8 to 007-002-0001472-1
# Data columns (total 71 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   NIT_OCTUBRE_2024                13293 non-null  object
#  1   Morosidad_OCTUBRE_2024          13293 non-null  float64
#  2   CodigoContable_OCTUBRE_2024     13293 non-null  float64
#  3   SALPRES_OCTUBRE_2024            13293 non-null  float64
#  4   VEA_OCTUBRE_2024                13293 non-null  float64
#  5   NIT_NOVIEMBRE_2024              13893 non-null  object
#  6   Morosidad_NOVIEMBRE_2024        13893 non-null  float64
#  7   CodigoContable_NOVIEMBRE_2024   13893 non-null  float64
#  8   SALPRES_NOVIEMBRE_2024          13893 non-null  float64
#  9   VEA_NOVIEMBRE_2024              13893 non-null  float64
#  10  clasegarantia_NOVIEMBRE_2024    13893 non-null  float64
#  11  NIT_DICIEMBRE_2024              14378 non-null  object
#  12  Morosidad_DICIEMBRE_2024        14378 non-null  float64
#  13  CodigoContable_DICIEMBRE_2024   14378 non-null  float64
#  14  SALPRES_DICIEMBRE_2024          14378 non-null  float64
#  15  VEA_DICIEMBRE_2024              14378 non-null  float64
#  16  clasegarantia_DICIEMBRE_2024    14378 non-null  float64
#  17  NIT_ENERO_2025                  14887 non-null  object
#  18  Morosidad_ENERO_2025            14887 non-null  float64
#  19  CodigoContable_ENERO_2025       14887 non-null  float64
#  20  SALPRES_ENERO_2025              14887 non-null  float64
#  21  VEA_ENERO_2025                  14887 non-null  float64
#  22  clasegarantia_ENERO_2025        14887 non-null  float64
#  23  NIT_FEBRERO_2025                15581 non-null  object
#  24  Morosidad_FEBRERO_2025          15581 non-null  float64
#  25  CodigoContable_FEBRERO_2025     15581 non-null  float64
#  26  SALPRES_FEBRERO_2025            15581 non-null  float64
#  27  VEA_FEBRERO_2025                15581 non-null  float64
#  28  clasegarantia_FEBRERO_2025      15581 non-null  float64
#  29  NIT_MARZO_2025                  16348 non-null  object
#  30  Morosidad_MARZO_2025            16348 non-null  float64
#  31  CodigoContable_MARZO_2025       16348 non-null  float64
#  32  SALPRES_MARZO_2025              16348 non-null  float64
#  33  VEA_MARZO_2025                  16348 non-null  float64
#  34  clasegarantia_MARZO_2025        16348 non-null  float64
#  35  NIT_ABRIL_2025                  17100 non-null  object
#  36  Morosidad_ABRIL_2025            17100 non-null  float64
#  37  CodigoContable_ABRIL_2025       17100 non-null  float64
#  38  SALPRES_ABRIL_2025              17100 non-null  float64
#  39  VEA_ABRIL_2025                  17100 non-null  float64
#  40  clasegarantia_ABRIL_2025        17100 non-null  float64
#  41  NIT_MAYO_2025                   18010 non-null  object
#  42  Morosidad_MAYO_2025             18010 non-null  float64
#  43  CodigoContable_MAYO_2025        18010 non-null  float64
#  44  SALPRES_MAYO_2025               18010 non-null  float64
#  45  VEA_MAYO_2025                   18010 non-null  float64
#  46  clasegarantia_MAYO_2025         18010 non-null  float64
#  47  NIT_JUNIO_2025                  18733 non-null  object
#  48  Morosidad_JUNIO_2025            18733 non-null  float64
#  49  CodigoContable_JUNIO_2025       18733 non-null  float64
#  50  SALPRES_JUNIO_2025              18733 non-null  float64
#  51  VEA_JUNIO_2025                  18733 non-null  float64
#  52  clasegarantia_JUNIO_2025        18733 non-null  float64
#  53  NIT_JULIO_2025                  19594 non-null  object
#  54  Morosidad_JULIO_2025            19594 non-null  float64
#  55  CodigoContable_JULIO_2025       19594 non-null  float64
#  56  SALPRES_JULIO_2025              19594 non-null  float64
#  57  VEA_JULIO_2025                  19594 non-null  float64
#  58  clasegarantia_JULIO_2025        19594 non-null  float64
#  59  NIT_AGOSTO_2025                 20231 non-null  object
#  60  Morosidad_AGOSTO_2025           20231 non-null  float64
#  61  CodigoContable_AGOSTO_2025      20231 non-null  float64
#  62  SALPRES_AGOSTO_2025             20231 non-null  float64
#  63  VEA_AGOSTO_2025                 20231 non-null  float64
#  64  clasegarantia_AGOSTO_2025       20231 non-null  float64
#  65  NIT_SEPTIEMBRE_2025             21020 non-null  object
#  66  Morosidad_SEPTIEMBRE_2025       21020 non-null  float64
#  67  CodigoContable_SEPTIEMBRE_2025  21020 non-null  float64
#  68  SALPRES_SEPTIEMBRE_2025         21020 non-null  float64
#  69  VEA_SEPTIEMBRE_2025             21020 non-null  float64
#  70  clasegarantia_SEPTIEMBRE_2025   21020 non-null  float64
# dtypes: float64(59), object(12)
# memory usage: 11.5+ MB

# %%
# Crear una columna nueva que sea el valor máximo de morosidad en los últimos 12 meses tomando únicamente las columnas que contienen la palabra "Morosidad"
df_mora[f'MORA12_{meses_ordenados[-1]}'] = df_mora.filter(like='Morosidad').max(axis=1, skipna=True)
df_mora # Muestra las primeras filas del DataFrame final
# Out:
# C:\Users\jhquiza\AppData\Local\Temp\ipykernel_30144\2550005945.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mora[f'MORA12_{meses_ordenados[-1]}'] = df_mora.filter(like='Morosidad').max(axis=1, skipna=True)
#                   NIT_OCTUBRE_2024  Morosidad_OCTUBRE_2024  \
# NroCredito
# 002-001-0000024-8    901-285-696-7                     0.0
# 002-001-0000026-6    900-698-421-8                     8.0
# 002-001-0000027-5    811-021-864-9                     0.0
# 002-001-0000028-4    900-409-773-7                     5.0
# 002-001-0000029-3    901-406-831-6                    30.0
# ...                            ...                     ...
# 007-002-0001463-2              NaN                     NaN
# 007-002-0001464-1              NaN                     NaN
# 007-002-0001467-8              NaN                     NaN
# 007-002-0001468-7              NaN                     NaN
# 007-002-0001472-1              NaN                     NaN
#
#                    CodigoContable_OCTUBRE_2024  SALPRES_OCTUBRE_2024  \
# NroCredito
# 002-001-0000024-8                     146205.0              0.447354
# 002-001-0000026-6                     146205.0              0.659054
# 002-001-0000027-5                     146205.0              0.787416
# 002-001-0000028-4                     146205.0              0.687549
# 002-001-0000029-3                     146205.0              0.895916
# ...                                        ...                   ...
# 007-002-0001463-2                          NaN                   NaN
# 007-002-0001464-1                          NaN                   NaN
# 007-002-0001467-8                          NaN                   NaN
# 007-002-0001468-7                          NaN                   NaN
# 007-002-0001472-1                          NaN                   NaN
#
#                    VEA_OCTUBRE_2024 NIT_NOVIEMBRE_2024  \
# NroCredito
# 002-001-0000024-8      2.244973e+07      901-285-696-7
# 002-001-0000026-6      6.697431e+07      900-698-421-8
# 002-001-0000027-5      1.853138e+09      811-021-864-9
# 002-001-0000028-4      1.399760e+08      900-409-773-7
# 002-001-0000029-3      6.521809e+08      901-406-831-6
# ...                             ...                ...
# 007-002-0001463-2               NaN                NaN
# 007-002-0001464-1               NaN                NaN
# 007-002-0001467-8               NaN                NaN
# 007-002-0001468-7               NaN                NaN
# 007-002-0001472-1               NaN                NaN
#
#                    Morosidad_NOVIEMBRE_2024  CodigoContable_NOVIEMBRE_2024  \
# NroCredito
# 002-001-0000024-8                       0.0                       146205.0
# 002-001-0000026-6                       8.0                       146205.0
# 002-001-0000027-5                       0.0                       146205.0
# 002-001-0000028-4                       5.0                       146205.0
# 002-001-0000029-3                       1.0                       146205.0
# ...                                     ...                            ...
# 007-002-0001463-2                       NaN                            NaN
# 007-002-0001464-1                       NaN                            NaN
# 007-002-0001467-8                       NaN                            NaN
# 007-002-0001468-7                       NaN                            NaN
# 007-002-0001472-1                       NaN                            NaN
#
#                    SALPRES_NOVIEMBRE_2024  VEA_NOVIEMBRE_2024  ...  \
# NroCredito                                                     ...
# 002-001-0000024-8                0.430239        2.155141e+07  ...
# 002-001-0000026-6                0.643515        6.541299e+07  ...
# 002-001-0000027-5                0.777588        1.830738e+09  ...
# 002-001-0000028-4                0.672469        1.369056e+08  ...
# 002-001-0000029-3                0.885822        6.441110e+08  ...
# ...                                   ...                 ...  ...
# 007-002-0001463-2                     NaN                 NaN  ...
# 007-002-0001464-1                     NaN                 NaN  ...
# 007-002-0001467-8                     NaN                 NaN  ...
# 007-002-0001468-7                     NaN                 NaN  ...
# 007-002-0001472-1                     NaN                 NaN  ...
#
#                    SALPRES_AGOSTO_2025 VEA_AGOSTO_2025  \
# NroCredito
# 002-001-0000024-8             0.259650    1.300153e+07
# 002-001-0000026-6             0.528942    5.328384e+07
# 002-001-0000027-5             0.685802    1.613352e+09
# 002-001-0000028-4             0.543393    1.113402e+08
# 002-001-0000029-3             0.848534    6.309995e+08
# ...                                ...             ...
# 007-002-0001463-2             0.936706    9.663460e+05
# 007-002-0001464-1             0.400000    4.002147e+06
# 007-002-0001467-8             0.887833    2.701704e+06
# 007-002-0001468-7             0.940565    4.778096e+06
# 007-002-0001472-1                  NaN             NaN
#
#                    clasegarantia_AGOSTO_2025  NIT_SEPTIEMBRE_2025  \
# NroCredito
# 002-001-0000024-8                        1.0        901-285-696-7
# 002-001-0000026-6                        1.0        900-698-421-8
# 002-001-0000027-5                        1.0        811-021-864-9
# 002-001-0000028-4                        1.0        900-409-773-7
# 002-001-0000029-3                        1.0        901-406-831-6
# ...                                      ...                  ...
# 007-002-0001463-2                        1.0           1035912774
# 007-002-0001464-1                        1.0             15437544
# 007-002-0001467-8                        1.0             43907525
# 007-002-0001468-7                        1.0           1036964056
# 007-002-0001472-1                        NaN           1001370322
#
#                    Morosidad_SEPTIEMBRE_2025  CodigoContable_SEPTIEMBRE_2025  \
# NroCredito
# 002-001-0000024-8                        0.0                        146515.0
# 002-001-0000026-6                       16.0                        146515.0
# 002-001-0000027-5                        6.0                        146515.0
# 002-001-0000028-4                        5.0                        146515.0
# 002-001-0000029-3                       91.0                        146525.0
# ...                                      ...                             ...
# 007-002-0001463-2                       44.0                        144210.0
# 007-002-0001464-1                        0.0                        144205.0
# 007-002-0001467-8                        0.0                        144205.0
# 007-002-0001468-7                       14.0                        144205.0
# 007-002-0001472-1                        0.0                        144205.0
#
#                    SALPRES_SEPTIEMBRE_2025 VEA_SEPTIEMBRE_2025  \
# NroCredito
# 002-001-0000024-8                 0.239269        1.199857e+07
# 002-001-0000026-6                 0.528942        5.395877e+07
# 002-001-0000027-5                 0.685802        1.632600e+09
# 002-001-0000028-4                 0.508649        1.027004e+08
# 002-001-0000029-3                 0.848534        6.309995e+08
# ...                                    ...                 ...
# 007-002-0001463-2                 0.936706        9.806260e+05
# 007-002-0001464-1                 0.400000        4.066557e+06
# 007-002-0001467-8                 0.880690        2.684521e+06
# 007-002-0001468-7                 0.940565        4.851986e+06
# 007-002-0001472-1                 0.623300        1.871907e+06
#
#                    clasegarantia_SEPTIEMBRE_2025  MORA12_SEPTIEMBRE_2025
# NroCredito
# 002-001-0000024-8                            1.0                     0.0
# 002-001-0000026-6                            1.0                    38.0
# 002-001-0000027-5                            1.0                     6.0
# 002-001-0000028-4                            1.0                    35.0
# 002-001-0000029-3                            1.0                    91.0
# ...                                          ...                     ...
# 007-002-0001463-2                            1.0                    44.0
# 007-002-0001464-1                            1.0                     0.0
# 007-002-0001467-8                            1.0                     0.0
# 007-002-0001468-7                            1.0                    14.0
# 007-002-0001472-1                            1.0                     0.0
#
# [21020 rows x 72 columns]

# %%
# Conservar solo las columnas que contienen el último mes
columnas_a_conservar = [f'Morosidad_{meses_ordenados[-1]}', 
                        f'CodigoContable_{meses_ordenados[-1]}', 
                        f'NIT_{meses_ordenados[-1]}', 
                        f'SALPRES_{meses_ordenados[-1]}', 
                        f'VEA_{meses_ordenados[-1]}', 
                        f'MORA12_{meses_ordenados[-1]}', 
                        f'clasegarantia_{meses_ordenados[-1]}']

df_mora = df_mora[columnas_a_conservar]
df_mora
# Out:
#                    Morosidad_SEPTIEMBRE_2025  CodigoContable_SEPTIEMBRE_2025  \
# NroCredito
# 002-001-0000024-8                        0.0                        146515.0
# 002-001-0000026-6                       16.0                        146515.0
# 002-001-0000027-5                        6.0                        146515.0
# 002-001-0000028-4                        5.0                        146515.0
# 002-001-0000029-3                       91.0                        146525.0
# ...                                      ...                             ...
# 007-002-0001463-2                       44.0                        144210.0
# 007-002-0001464-1                        0.0                        144205.0
# 007-002-0001467-8                        0.0                        144205.0
# 007-002-0001468-7                       14.0                        144205.0
# 007-002-0001472-1                        0.0                        144205.0
#
#                   NIT_SEPTIEMBRE_2025  SALPRES_SEPTIEMBRE_2025  \
# NroCredito
# 002-001-0000024-8       901-285-696-7                 0.239269
# 002-001-0000026-6       900-698-421-8                 0.528942
# 002-001-0000027-5       811-021-864-9                 0.685802
# 002-001-0000028-4       900-409-773-7                 0.508649
# 002-001-0000029-3       901-406-831-6                 0.848534
# ...                               ...                      ...
# 007-002-0001463-2          1035912774                 0.936706
# 007-002-0001464-1            15437544                 0.400000
# 007-002-0001467-8            43907525                 0.880690
# 007-002-0001468-7          1036964056                 0.940565
# 007-002-0001472-1          1001370322                 0.623300
#
#                    VEA_SEPTIEMBRE_2025  MORA12_SEPTIEMBRE_2025  \
# NroCredito
# 002-001-0000024-8         1.199857e+07                     0.0
# 002-001-0000026-6         5.395877e+07                    38.0
# 002-001-0000027-5         1.632600e+09                     6.0
# 002-001-0000028-4         1.027004e+08                    35.0
# 002-001-0000029-3         6.309995e+08                    91.0
# ...                                ...                     ...
# 007-002-0001463-2         9.806260e+05                    44.0
# 007-002-0001464-1         4.066557e+06                     0.0
# 007-002-0001467-8         2.684521e+06                     0.0
# 007-002-0001468-7         4.851986e+06                    14.0
# 007-002-0001472-1         1.871907e+06                     0.0
#
#                    clasegarantia_SEPTIEMBRE_2025
# NroCredito
# 002-001-0000024-8                            1.0
# 002-001-0000026-6                            1.0
# 002-001-0000027-5                            1.0
# 002-001-0000028-4                            1.0
# 002-001-0000029-3                            1.0
# ...                                          ...
# 007-002-0001463-2                            1.0
# 007-002-0001464-1                            1.0
# 007-002-0001467-8                            1.0
# 007-002-0001468-7                            1.0
# 007-002-0001472-1                            1.0
#
# [21020 rows x 7 columns]

# %%
import numpy as np

# Quitar el mes y el año de los nombres de las columnas
new_column_names = {f'Morosidad_{meses_ordenados[-1]}': 'Morosidad',
                        f'CodigoContable_{meses_ordenados[-1]}': 'CodigoContable',
                        f'NIT_{meses_ordenados[-1]}': 'NIT',
                        f'SALPRES_{meses_ordenados[-1]}': 'SALPRES',
                        f'VEA_{meses_ordenados[-1]}': 'VEA',
                        f'MORA12_{meses_ordenados[-1]}': 'MORA12',
                        f'clasegarantia_{meses_ordenados[-1]}': 'clasegarantia'
                        }

df_mora = df_mora.rename(columns=new_column_names)
df_mora = df_mora.reset_index()
df_mora['SINMORA'] = np.where(df_mora['MORA12'] == 0, 1, 0)
df_mora
# Out:
#               NroCredito  Morosidad  CodigoContable            NIT   SALPRES  \
# 0      002-001-0000024-8        0.0        146515.0  901-285-696-7  0.239269
# 1      002-001-0000026-6       16.0        146515.0  900-698-421-8  0.528942
# 2      002-001-0000027-5        6.0        146515.0  811-021-864-9  0.685802
# 3      002-001-0000028-4        5.0        146515.0  900-409-773-7  0.508649
# 4      002-001-0000029-3       91.0        146525.0  901-406-831-6  0.848534
# ...                  ...        ...             ...            ...       ...
# 21015  007-002-0001463-2       44.0        144210.0     1035912774  0.936706
# 21016  007-002-0001464-1        0.0        144205.0       15437544  0.400000
# 21017  007-002-0001467-8        0.0        144205.0       43907525  0.880690
# 21018  007-002-0001468-7       14.0        144205.0     1036964056  0.940565
# 21019  007-002-0001472-1        0.0        144205.0     1001370322  0.623300
#
#                 VEA  MORA12  clasegarantia  SINMORA
# 0      1.199857e+07     0.0            1.0        1
# 1      5.395877e+07    38.0            1.0        0
# 2      1.632600e+09     6.0            1.0        0
# 3      1.027004e+08    35.0            1.0        0
# 4      6.309995e+08    91.0            1.0        0
# ...             ...     ...            ...      ...
# 21015  9.806260e+05    44.0            1.0        0
# 21016  4.066557e+06     0.0            1.0        1
# 21017  2.684521e+06     0.0            1.0        1
# 21018  4.851986e+06    14.0            1.0        0
# 21019  1.871907e+06     0.0            1.0        1
#
# [21020 rows x 9 columns]

# %%
# Crear una nueva columna llamada PDI que se calcula así:
# Si clasegarantia es igual a 1 o a 4, entonces:
#  Si Morosidad >= 420, PDI = 1.0,
#  Si Morosidad < 420 y Morosidad >= 210, PDI = 0.7,
#  Si Morosidad < 210, PDI = 0.6,
#  Si Morosidad < 90, PDI = 0.45,


# Si clasegarantia es igual a 2, entonces:
#  Si Morosidad >= 720, PDI = 1.0,
#  Si Morosidad < 720 y Morosidad >= 360, PDI = 0.7,
#  Si Morosidad < 360, PDI = 0.4,
# Si clasegarantia es igual a 3, entonces:
#  Si Morosidad >= 540, PDI = 1.0,
#  Si Morosidad < 540 y Morosidad >= 270, PDI = 0.7,
#  Si Morosidad < 270, PDI = 0.5

def calcular_pdi(row):
    clase = row['clasegarantia']
    morosidad = row['Morosidad']
    
    if clase in [1, 4]:
        if morosidad >= 420:
            return 1.0
        elif morosidad >= 210:
            return 0.7
        elif morosidad >= 90:
            return 0.6
        else:
            return 0.45
    elif clase == 2:
        if morosidad >= 720:
            return 1.0
        elif morosidad >= 360:
            return 0.7
        else:
            return 0.4
    elif clase == 3:
        if morosidad >= 540:
            return 1.0
        elif morosidad >= 270:
            return 0.7
        else:
            return 0.5
    else:
        return np.nan

df_mora['PDI'] = df_mora.apply(calcular_pdi, axis=1)
df_mora
# Out:
#               NroCredito  Morosidad  CodigoContable            NIT   SALPRES  \
# 0      002-001-0000024-8        0.0        146515.0  901-285-696-7  0.239269
# 1      002-001-0000026-6       16.0        146515.0  900-698-421-8  0.528942
# 2      002-001-0000027-5        6.0        146515.0  811-021-864-9  0.685802
# 3      002-001-0000028-4        5.0        146515.0  900-409-773-7  0.508649
# 4      002-001-0000029-3       91.0        146525.0  901-406-831-6  0.848534
# ...                  ...        ...             ...            ...       ...
# 21015  007-002-0001463-2       44.0        144210.0     1035912774  0.936706
# 21016  007-002-0001464-1        0.0        144205.0       15437544  0.400000
# 21017  007-002-0001467-8        0.0        144205.0       43907525  0.880690
# 21018  007-002-0001468-7       14.0        144205.0     1036964056  0.940565
# 21019  007-002-0001472-1        0.0        144205.0     1001370322  0.623300
#
#                 VEA  MORA12  clasegarantia  SINMORA   PDI
# 0      1.199857e+07     0.0            1.0        1  0.45
# 1      5.395877e+07    38.0            1.0        0  0.45
# 2      1.632600e+09     6.0            1.0        0  0.45
# 3      1.027004e+08    35.0            1.0        0  0.45
# 4      6.309995e+08    91.0            1.0        0  0.60
# ...             ...     ...            ...      ...   ...
# 21015  9.806260e+05    44.0            1.0        0  0.45
# 21016  4.066557e+06     0.0            1.0        1  0.45
# 21017  2.684521e+06     0.0            1.0        1  0.45
# 21018  4.851986e+06    14.0            1.0        0  0.45
# 21019  1.871907e+06     0.0            1.0        1  0.45
#
# [21020 rows x 10 columns]

# %% [markdown]
# # Antiguedad (ANTI) y Activo

# %%
# Cargar el archivo 'Archivos originales/INFORME ASOCIADOS_JUNIO_2022.xlsx' en un dataframe llamado 'vinculacion_{mes_año}' donde {mes_año} está extraído del nombre del archivo

archivo = 'INFORME ASOCIADOS_SEPTIEMBRE_2025.xlsx'
mes_anno = archivo.split('.')[0]
mes_anno = mes_anno.split('_', maxsplit=1)[1]
mes_anno

nombre_df = f'vinculacion_{mes_anno}'
vinculaciones = {}
vinculaciones[nombre_df] = pd.read_excel(
    archivo,
    header=3
)

vinculaciones[nombre_df]['Fecha de ingreso'] = pd.to_datetime(vinculaciones[nombre_df]['Fecha de ingreso'], errors='coerce', format='%d/%m/%Y')
vinculaciones[nombre_df]['Activo'] = vinculaciones[nombre_df]['Activo'].fillna(1).astype(int)
vinculaciones[nombre_df].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50239 entries, 0 to 50238
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Número de identificación  50239 non-null  object
#  1   Nombres                   50239 non-null  object
#  2   Primer apellido           49937 non-null  object
#  3   Activo                    50239 non-null  int32
#  4   Fecha de ingreso          50239 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int32(1), object(3)
# memory usage: 1.7+ MB

# %%
# Crear una columna nueva llamada 'Activo desde' que contenga el número de días que lleva activo el cliente desde la fecha de ingreso hasta el último día del mes que orresponde a la variable mes_anno. Si 'Activo' es 0 o Nan, entonces esta variable también será 0
ultimo_dia_mes = mes_ano_to_date(mes_anno) + pd.offsets.MonthEnd(0)
vinculaciones[nombre_df]['ANTI'] = vinculaciones[nombre_df]['Activo'] * (ultimo_dia_mes - vinculaciones[nombre_df]['Fecha de ingreso']).dt.days
vinculaciones[nombre_df]
# Out:
#       Número de identificación                       Nombres Primer apellido  \
# 0                        96055                 Felix Antonio         Castaño
# 1                       152419                       Jacques        Fournier
# 2                       179810                         Edwin          Arenas
# 3                       204414                   Lina Zulema        Pedrazas
# 4                       219552                German Rodrigo       Tenelanda
# ...                        ...                           ...             ...
# 50234            901-792-877-8  Inversiones Saint Polito Sas             NaN
# 50235          1-037-614-537-4   Villegas Tobon Leidy Johana             NaN
# 50236          825276723041978            Katerine Del Valle       Hernandez
# 50237          924835703011983               Gabriel Eduardo         Joaquim
# 50238          938711918091996                 Alba Carolina          Urbina
#
#        Activo Fecha de ingreso  ANTI
# 0           1       2002-05-18  8536
# 1           1       2012-02-24  4967
# 2           1       2015-12-15  3577
# 3           1       2019-01-28  2437
# 4           1       2002-05-25  8529
# ...       ...              ...   ...
# 50234       1       2024-02-21   587
# 50235       1       2022-08-03  1154
# 50236       1       2021-06-30  1553
# 50237       1       2020-02-01  2068
# 50238       1       2021-09-23  1468
#
# [50239 rows x 6 columns]

# %%
# Fusionar el dataframe df_mora con el dataframe vinculaciones[nombre_df] usando como clave primaria la columna 'NIT' de df_mora y la columna 'Número de identificación' de vinculaciones[nombre_df], usando el método left
df_features = pd.merge(
    df_mora[['NroCredito','NIT', 'CodigoContable', 'SALPRES', 'VEA','MORA12','SINMORA', 'Morosidad', 'clasegarantia', 'PDI']], 
    vinculaciones[nombre_df][['Número de identificación', 'Activo', 'ANTI']], 
    left_on='NIT', 
    right_on='Número de identificación', 
    how='left'
)

df_features = df_features.drop(columns=['Número de identificación'])
df_features
# Out:
#               NroCredito            NIT  CodigoContable   SALPRES  \
# 0      002-001-0000024-8  901-285-696-7        146515.0  0.239269
# 1      002-001-0000026-6  900-698-421-8        146515.0  0.528942
# 2      002-001-0000027-5  811-021-864-9        146515.0  0.685802
# 3      002-001-0000028-4  900-409-773-7        146515.0  0.508649
# 4      002-001-0000029-3  901-406-831-6        146525.0  0.848534
# ...                  ...            ...             ...       ...
# 21015  007-002-0001463-2     1035912774        144210.0  0.936706
# 21016  007-002-0001464-1       15437544        144205.0  0.400000
# 21017  007-002-0001467-8       43907525        144205.0  0.880690
# 21018  007-002-0001468-7     1036964056        144205.0  0.940565
# 21019  007-002-0001472-1     1001370322        144205.0  0.623300
#
#                 VEA  MORA12  SINMORA  Morosidad  clasegarantia   PDI  Activo  \
# 0      1.199857e+07     0.0        1        0.0            1.0  0.45     1.0
# 1      5.395877e+07    38.0        0       16.0            1.0  0.45     1.0
# 2      1.632600e+09     6.0        0        6.0            1.0  0.45     1.0
# 3      1.027004e+08    35.0        0        5.0            1.0  0.45     1.0
# 4      6.309995e+08    91.0        0       91.0            1.0  0.60     1.0
# ...             ...     ...      ...        ...            ...   ...     ...
# 21015  9.806260e+05    44.0        0       44.0            1.0  0.45     1.0
# 21016  4.066557e+06     0.0        1        0.0            1.0  0.45     1.0
# 21017  2.684521e+06     0.0        1        0.0            1.0  0.45     1.0
# 21018  4.851986e+06    14.0        0       14.0            1.0  0.45     1.0
# 21019  1.871907e+06     0.0        1        0.0            1.0  0.45     1.0
#
#          ANTI
# 0      1448.0
# 1      1181.0
# 2      1791.0
# 3      1141.0
# 4      1131.0
# ...       ...
# 21015  1457.0
# 21016  6405.0
# 21017   463.0
# 21018   564.0
# 21019  5024.0
#
# [21020 rows x 12 columns]

# %% [markdown]
# # Aportes (AP)

# %%
archivo = 'INFORME INDIVIDUAL DE APORTES_SEPTIEMBRE_2025.xlsx'
mes_anno = archivo.split('.')[0]
mes_anno = mes_anno.split('_', maxsplit=1)[1]
mes_anno

nombre_df = f'aporte_{mes_anno}'
aportes = {}
aportes[nombre_df] = pd.read_excel(
    archivo,
    header=3
)

aportes[nombre_df]['Aporte/Contribución Ordinario'] = aportes[nombre_df]['Aporte/Contribución Ordinario'].fillna(0)
aportes[nombre_df] = aportes[nombre_df].rename(columns={'Aporte/Contribución Ordinario': 'AP'})  
aportes[nombre_df].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46767 entries, 0 to 46766
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Tipo identificación                 46767 non-null  object
#  1   Número de identificación            46767 non-null  int64
#  2   Saldo a fecha                       46767 non-null  float64
#  3   Valor Aporte/Contribución Mensual   46767 non-null  int64
#  4   AP                                  46767 non-null  float64
#  5   Aporte/Contribución ExtraOrdinario  46767 non-null  int64
#  6   ValorRevalorizacion                 46767 non-null  int64
#  7   Monto Promedio                      46767 non-null  int64
#  8   UltimaFecha                         46767 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(5), object(1)
# memory usage: 3.2+ MB

# %%
# Fusionar el dataframe df_features con el dataframe aportes[nombre_df] usando como clave primaria la columna 'NIT' de df_features y la columna 'Número de identificación' de aportes[nombre_df], usando el método left
df_features = pd.merge(
    df_features, 
    aportes[nombre_df][['Número de identificación', 'AP']], 
    left_on='NIT', 
    right_on='Número de identificación', 
    how='left'
    )

df_features = df_features.drop(columns=['Número de identificación'])
df_features
# Out:
#               NroCredito            NIT  CodigoContable   SALPRES  \
# 0      002-001-0000024-8  901-285-696-7        146515.0  0.239269
# 1      002-001-0000026-6  900-698-421-8        146515.0  0.528942
# 2      002-001-0000027-5  811-021-864-9        146515.0  0.685802
# 3      002-001-0000028-4  900-409-773-7        146515.0  0.508649
# 4      002-001-0000029-3  901-406-831-6        146525.0  0.848534
# ...                  ...            ...             ...       ...
# 21015  007-002-0001463-2     1035912774        144210.0  0.936706
# 21016  007-002-0001464-1       15437544        144205.0  0.400000
# 21017  007-002-0001467-8       43907525        144205.0  0.880690
# 21018  007-002-0001468-7     1036964056        144205.0  0.940565
# 21019  007-002-0001472-1     1001370322        144205.0  0.623300
#
#                 VEA  MORA12  SINMORA  Morosidad  clasegarantia   PDI  Activo  \
# 0      1.199857e+07     0.0        1        0.0            1.0  0.45     1.0
# 1      5.395877e+07    38.0        0       16.0            1.0  0.45     1.0
# 2      1.632600e+09     6.0        0        6.0            1.0  0.45     1.0
# 3      1.027004e+08    35.0        0        5.0            1.0  0.45     1.0
# 4      6.309995e+08    91.0        0       91.0            1.0  0.60     1.0
# ...             ...     ...      ...        ...            ...   ...     ...
# 21015  9.806260e+05    44.0        0       44.0            1.0  0.45     1.0
# 21016  4.066557e+06     0.0        1        0.0            1.0  0.45     1.0
# 21017  2.684521e+06     0.0        1        0.0            1.0  0.45     1.0
# 21018  4.851986e+06    14.0        0       14.0            1.0  0.45     1.0
# 21019  1.871907e+06     0.0        1        0.0            1.0  0.45     1.0
#
#          ANTI          AP
# 0      1448.0         NaN
# 1      1181.0         NaN
# 2      1791.0         NaN
# 3      1141.0         NaN
# 4      1131.0         NaN
# ...       ...         ...
# 21015  1457.0  2418121.00
# 21016  6405.0  2020640.00
# 21017   463.0   775001.00
# 21018   564.0   945001.00
# 21019  5024.0  1481471.88
#
# [21020 rows x 13 columns]

# %% [markdown]
# # Ahorro CDAT (COOCDAT)

# %%
archivo = 'INFORME INDIVIDUAL DE LAS CAPTACIONES (MODIFICADO)_SEPTIEMBRE_2025.xlsx'
mes_anno = archivo.split('.')[0]
mes_anno = mes_anno.split('_', maxsplit=1)[1]
mes_anno

nombre_df = f'captacion_{mes_anno}'
captaciones = {}
captaciones[nombre_df] = pd.read_excel(
    archivo,
    header=3
)

captaciones[nombre_df].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57345 entries, 0 to 57344
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   TipoIden             57345 non-null  object
#  1   NIT                  57345 non-null  object
#  2   CodigoContable       57345 non-null  int64
#  3   NombreDeposito       57345 non-null  object
#  4   TipoAhorro           57345 non-null  int64
#  5   Amortizacion         57345 non-null  int64
#  6   FechaApertura        57345 non-null  datetime64[ns]
#  7   Plazo                57345 non-null  int64
#  8   FechaVencimiento     32103 non-null  datetime64[ns]
#  9   Modalidad            57345 non-null  int64
#  10  TasaInteresNominal   57345 non-null  float64
#  11  TasaInteresEfectiva  57345 non-null  float64
#  12  InteresesCausados    57345 non-null  int64
#  13  Saldo                57345 non-null  float64
#  14  DepositoInicial      57345 non-null  float64
#  15  NumeroCuenta         57345 non-null  int64
#  16  excentagmf           57345 non-null  int64
#  17  fechaaceptacionegmf  997 non-null    datetime64[ns]
#  18  Estado               57345 non-null  int64
#  19  CtaBajoMonto         57345 non-null  int64
#  20  Cotitulares          57345 non-null  int64
#  21  ConjuntaColectivo    0 non-null      float64
# dtypes: datetime64[ns](3), float64(5), int64(11), object(3)
# memory usage: 9.6+ MB

# %%
# Crear una columna llamada 'es CDAT' que sea igual a 1 si la columna 'NombreDeposito' contiene la palabra 'CDAT' y 0 en caso contrario
captaciones[nombre_df]['es CDAT'] = captaciones[nombre_df]['NombreDeposito'].str.contains('CDAT', case=False, na=False).astype(int)
captaciones[nombre_df]['COOCDAT'] = captaciones[nombre_df]['es CDAT'] * captaciones[nombre_df]['Saldo']
captaciones[nombre_df] = captaciones[nombre_df][captaciones[nombre_df]['es CDAT']==1]
captaciones[nombre_df] = captaciones[nombre_df][['NIT', 'COOCDAT']]

# Agrupar por NIT y sumar COOCDAT
captaciones[nombre_df] = captaciones[nombre_df].groupby('NIT').sum().reset_index()
# Mostrar la información del dataframe 
captaciones[nombre_df].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4054 entries, 0 to 4053
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   NIT      4054 non-null   object
#  1   COOCDAT  4054 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 63.5+ KB

# %%
captaciones[nombre_df] = captaciones[nombre_df].rename(columns={'NIT': 'NIT_1'})
df_all_features = pd.merge(
    df_features, 
    captaciones[nombre_df], 
    left_on='NIT', 
    right_on='NIT_1', 
    how='left'
    )

df_all_features = df_all_features.drop(columns=['NIT_1'])
df_all_features
# Out:
#               NroCredito            NIT  CodigoContable   SALPRES  \
# 0      002-001-0000024-8  901-285-696-7        146515.0  0.239269
# 1      002-001-0000026-6  900-698-421-8        146515.0  0.528942
# 2      002-001-0000027-5  811-021-864-9        146515.0  0.685802
# 3      002-001-0000028-4  900-409-773-7        146515.0  0.508649
# 4      002-001-0000029-3  901-406-831-6        146525.0  0.848534
# ...                  ...            ...             ...       ...
# 21015  007-002-0001463-2     1035912774        144210.0  0.936706
# 21016  007-002-0001464-1       15437544        144205.0  0.400000
# 21017  007-002-0001467-8       43907525        144205.0  0.880690
# 21018  007-002-0001468-7     1036964056        144205.0  0.940565
# 21019  007-002-0001472-1     1001370322        144205.0  0.623300
#
#                 VEA  MORA12  SINMORA  Morosidad  clasegarantia   PDI  Activo  \
# 0      1.199857e+07     0.0        1        0.0            1.0  0.45     1.0
# 1      5.395877e+07    38.0        0       16.0            1.0  0.45     1.0
# 2      1.632600e+09     6.0        0        6.0            1.0  0.45     1.0
# 3      1.027004e+08    35.0        0        5.0            1.0  0.45     1.0
# 4      6.309995e+08    91.0        0       91.0            1.0  0.60     1.0
# ...             ...     ...      ...        ...            ...   ...     ...
# 21015  9.806260e+05    44.0        0       44.0            1.0  0.45     1.0
# 21016  4.066557e+06     0.0        1        0.0            1.0  0.45     1.0
# 21017  2.684521e+06     0.0        1        0.0            1.0  0.45     1.0
# 21018  4.851986e+06    14.0        0       14.0            1.0  0.45     1.0
# 21019  1.871907e+06     0.0        1        0.0            1.0  0.45     1.0
#
#          ANTI          AP  COOCDAT
# 0      1448.0         NaN      NaN
# 1      1181.0         NaN      NaN
# 2      1791.0         NaN      NaN
# 3      1141.0         NaN      NaN
# 4      1131.0         NaN      NaN
# ...       ...         ...      ...
# 21015  1457.0  2418121.00      NaN
# 21016  6405.0  2020640.00      NaN
# 21017   463.0   775001.00      NaN
# 21018   564.0   945001.00      NaN
# 21019  5024.0  1481471.88      NaN
#
# [21020 rows x 14 columns]

# %%
df_all_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21020 entries, 0 to 21019
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NroCredito      21020 non-null  object
#  1   NIT             21020 non-null  object
#  2   CodigoContable  21020 non-null  float64
#  3   SALPRES         21020 non-null  float64
#  4   VEA             21020 non-null  float64
#  5   MORA12          21020 non-null  float64
#  6   SINMORA         21020 non-null  int32
#  7   Morosidad       21020 non-null  float64
#  8   clasegarantia   21020 non-null  float64
#  9   PDI             21020 non-null  float64
#  10  Activo          21016 non-null  float64
#  11  ANTI            21016 non-null  float64
#  12  AP              19970 non-null  float64
#  13  COOCDAT         669 non-null    float64
# dtypes: float64(11), int32(1), object(2)
# memory usage: 2.2+ MB

# %% [markdown]
# # Estimaciones de calificación crédito con libranza y sin libranza

# %%
cod_con_libranza = [141105, 141110, 141115, 141120, 144105, 144110, 144115, 144120, 144125]
cod_sin_libranza = [141205, 141210, 141215, 141220, 141225, 144205, 144210, 144215, 144220, 144225]

# %%
df_con_libranza = df_all_features[df_all_features['CodigoContable'].isin(cod_con_libranza)].copy()
df_con_libranza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7787 entries, 38 to 20649
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NroCredito      7787 non-null   object
#  1   NIT             7787 non-null   object
#  2   CodigoContable  7787 non-null   float64
#  3   SALPRES         7787 non-null   float64
#  4   VEA             7787 non-null   float64
#  5   MORA12          7787 non-null   float64
#  6   SINMORA         7787 non-null   int32
#  7   Morosidad       7787 non-null   float64
#  8   clasegarantia   7787 non-null   float64
#  9   PDI             7787 non-null   float64
#  10  Activo          7787 non-null   float64
#  11  ANTI            7787 non-null   float64
#  12  AP              7786 non-null   float64
#  13  COOCDAT         113 non-null    float64
# dtypes: float64(11), int32(1), object(2)
# memory usage: 882.1+ KB

# %%
df_con_libranza['COOCDAT']= df_con_libranza['COOCDAT'].fillna(0)
df_con_libranza = df_con_libranza[df_con_libranza['Activo'] == 1]
df_con_libranza['AP'] = df_con_libranza['AP'].fillna(0)
df_con_libranza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7786 entries, 38 to 20649
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NroCredito      7786 non-null   object
#  1   NIT             7786 non-null   object
#  2   CodigoContable  7786 non-null   float64
#  3   SALPRES         7786 non-null   float64
#  4   VEA             7786 non-null   float64
#  5   MORA12          7786 non-null   float64
#  6   SINMORA         7786 non-null   int32
#  7   Morosidad       7786 non-null   float64
#  8   clasegarantia   7786 non-null   float64
#  9   PDI             7786 non-null   float64
#  10  Activo          7786 non-null   float64
#  11  ANTI            7786 non-null   float64
#  12  AP              7786 non-null   float64
#  13  COOCDAT         7786 non-null   float64
# dtypes: float64(11), int32(1), object(2)
# memory usage: 882.0+ KB

# %%
# Cargar modelo 'lgbm_model_con_libranza.pkl' y crear en el dataframe 'df_con_libranza' una columna llamada Z con las predicciones del modelo
import joblib

vars_con_libranza = ['AP', 'COOCDAT', 'MORA12', 'SINMORA', 'ANTI']
lgbm_model_con_libranza = joblib.load('lightgbm_con_libranza_nov_2025.joblib')
df_con_libranza['Calif.modelo'] = lgbm_model_con_libranza.predict(df_con_libranza[vars_con_libranza])
df_con_libranza
# Out:
#               NroCredito       NIT  CodigoContable   SALPRES         VEA  \
# 38     002-002-0096598-0  71648448        144105.0  0.030641    899571.0
# 44     002-002-0098148-1  98488766        144105.0  0.283385   9285591.0
# 49     002-002-0099325-4  98595907        144105.0  0.682244  52568339.0
# 106    002-002-0108169-2  43983251        144105.0  0.212897   2997504.0
# 118    002-002-0108733-9  71648785        141105.0  0.053903    960344.0
# ...                  ...       ...             ...       ...         ...
# 20638  006-002-0036302-9  86061031        144105.0  1.000000  33023529.0
# 20641  006-002-0036305-6  15431170        144105.0  1.000000   1653420.0
# 20644  006-002-0036312-7  71382018        144105.0  1.000000  10043347.0
# 20645  006-002-0036315-4  10126913        141105.0  1.000000   1425950.0
# 20649  006-002-0036333-2  15442864        144105.0  1.000000   1010370.0
#
#        MORA12  SINMORA  Morosidad  clasegarantia   PDI  Activo    ANTI  \
# 38        0.0        1        0.0            1.0  0.45     1.0  5445.0
# 44        0.0        1        0.0            1.0  0.45     1.0  5414.0
# 49       11.0        0       11.0            1.0  0.45     1.0  4837.0
# 106       0.0        1        0.0            1.0  0.45     1.0  6542.0
# 118       8.0        0        8.0            1.0  0.45     1.0  7699.0
# ...       ...      ...        ...            ...   ...     ...     ...
# 20638     0.0        1        0.0            1.0  0.45     1.0  5425.0
# 20641     0.0        1        0.0            1.0  0.45     1.0   516.0
# 20644     0.0        1        0.0            1.0  0.45     1.0  3202.0
# 20645     0.0        1        0.0            1.0  0.45     1.0  2201.0
# 20649     0.0        1        0.0            1.0  0.45     1.0   313.0
#
#                AP  COOCDAT  Calif.modelo
# 38      5844817.0      0.0             0
# 44      7105694.0      0.0             0
# 49     24388732.0      0.0             0
# 106     7448554.0      0.0             0
# 118    10945912.5      0.0             0
# ...           ...      ...           ...
# 20638  11004175.0      0.0             0
# 20641    455907.0      0.0             0
# 20644   3545425.0      0.0             0
# 20645   1544370.0      0.0             0
# 20649    279001.0      0.0             0
#
# [7786 rows x 15 columns]

# %%
df_con_libranza['MORA12'].describe()
# Out:
# count    7786.000000
# mean        1.944387
# std        17.189058
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       843.000000
# Name: MORA12, dtype: float64

# %%
df_con_libranza['Calif.modelo'].value_counts()
# Out:
# Calif.modelo
# 0    7643
# 1      87
# 2      56
# Name: count, dtype: int64

# %%
df_con_libranza['Calif.modelo'] = df_con_libranza['Calif.modelo'].map({0: 'A', 1: 'B', 2: 'C', 3:'D'})

# %%
# Crear columna 'Calif.homologada', que se calcula así:
# Si 'Calif.modelo' es A, entonces 'Calif.homologada' es A
# Si 'Calif.modelo' es B, y 'MORA12' es menor o igual a 30, entonces 'Calif.homologada' es A
# Si 'Calif.modelo' es B, y 'MORA12' es mayor a 30, entonces 'Calif.homologada' es B
# Si 'Calif.modelo' es C, y 'MORA12' es menor o igual a 30, entonces 'Calif.homologada' es B
# Si 'Calif.modelo' es C, y 'MORA12' es mayor a 30, entonces 'Calif.homologada' es C
# Si 'Calif.modelo' es D o E, entonces 'Calif.homologada' es C
# Si 'MORA12' es mayor o igual a 90, y menor o igual a 180, entonces 'Calif.homologada' es D
# Si 'MORA12' es mayor a 180, entonces 'Calif.homologada' es E

condiciones = [
    (df_con_libranza['Calif.modelo'] == 'A'),
    (df_con_libranza['Calif.modelo'] == 'B') & (df_con_libranza['MORA12'] <= 30),
    (df_con_libranza['Calif.modelo'] == 'B') & (df_con_libranza['MORA12'] > 30) & (df_con_libranza['MORA12'] < 90),
    (df_con_libranza['Calif.modelo'] == 'C') & (df_con_libranza['MORA12'] <= 30),
    (df_con_libranza['Calif.modelo'] == 'C') & (df_con_libranza['MORA12'] > 30) & (df_con_libranza['MORA12'] < 90),
    (df_con_libranza['Calif.modelo'].isin(['D', 'E'])),
    (df_con_libranza['MORA12'].between(90, 180))
]

opciones = ['A', 'A', 'B', 'B', 'C', 'C', 'D']

df_con_libranza['Calif.homologada'] = np.select(condiciones, opciones, default='E')

# %%
df_con_libranza['Calif.homologada'].value_counts()
# Out:
# Calif.homologada
# A    7643
# B      87
# C      24
# D      22
# E      10
# Name: count, dtype: int64

# %% [markdown]
# ## Sin libranza

# %%
df_sin_libranza = df_all_features[df_all_features['CodigoContable'].isin(cod_sin_libranza)].copy()
df_sin_libranza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13092 entries, 9 to 21019
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NroCredito      13092 non-null  object
#  1   NIT             13092 non-null  object
#  2   CodigoContable  13092 non-null  float64
#  3   SALPRES         13092 non-null  float64
#  4   VEA             13092 non-null  float64
#  5   MORA12          13092 non-null  float64
#  6   SINMORA         13092 non-null  int32
#  7   Morosidad       13092 non-null  float64
#  8   clasegarantia   13092 non-null  float64
#  9   PDI             13092 non-null  float64
#  10  Activo          13090 non-null  float64
#  11  ANTI            13090 non-null  float64
#  12  AP              12102 non-null  float64
#  13  COOCDAT         550 non-null    float64
# dtypes: float64(11), int32(1), object(2)
# memory usage: 1.4+ MB

# %%
df_sin_libranza[['Activo', 'ANTI', 'AP']]= df_sin_libranza[['Activo', 'ANTI', 'AP']].fillna(0)
df_sin_libranza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13092 entries, 9 to 21019
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NroCredito      13092 non-null  object
#  1   NIT             13092 non-null  object
#  2   CodigoContable  13092 non-null  float64
#  3   SALPRES         13092 non-null  float64
#  4   VEA             13092 non-null  float64
#  5   MORA12          13092 non-null  float64
#  6   SINMORA         13092 non-null  int32
#  7   Morosidad       13092 non-null  float64
#  8   clasegarantia   13092 non-null  float64
#  9   PDI             13092 non-null  float64
#  10  Activo          13092 non-null  float64
#  11  ANTI            13092 non-null  float64
#  12  AP              13092 non-null  float64
#  13  COOCDAT         550 non-null    float64
# dtypes: float64(11), int32(1), object(2)
# memory usage: 1.4+ MB

# %%
vars_sin_libranza = ['Activo', 'ANTI', 'SALPRES', 'AP', 'MORA12']

lgbm_model_sin_libranza = joblib.load('lightgbm_sin_libranza_nov_2025.joblib')
df_sin_libranza['Calif.modelo'] = lgbm_model_sin_libranza.predict(df_sin_libranza[vars_sin_libranza])
df_sin_libranza
# Out:
#               NroCredito         NIT  CodigoContable   SALPRES         VEA  \
# 9      002-002-0013891-9    43801451        141210.0  0.264425   5345039.0
# 10     002-002-0048982-5    16224395        141225.0  0.310797  20012765.0
# 11     002-002-0054500-6    70130524        144225.0  0.912728  18820457.0
# 12     002-002-0063582-8    32523503        144205.0  0.044911    922145.0
# 13     002-002-0067978-1    71338874        144225.0  0.717959   7107791.0
# ...                  ...         ...             ...       ...         ...
# 21015  007-002-0001463-2  1035912774        144210.0  0.936706    980626.0
# 21016  007-002-0001464-1    15437544        144205.0  0.400000   4066557.0
# 21017  007-002-0001467-8    43907525        144205.0  0.880690   2684521.0
# 21018  007-002-0001468-7  1036964056        144205.0  0.940565   4851986.0
# 21019  007-002-0001472-1  1001370322        144205.0  0.623300   1871907.0
#
#        MORA12  SINMORA  Morosidad  clasegarantia   PDI  Activo    ANTI  \
# 9       217.0        0       53.0            3.0  0.50     0.0     0.0
# 10     3796.0        0     3796.0            1.0  1.00     0.0     0.0
# 11     3560.0        0     3560.0            1.0  1.00     0.0     0.0
# 12        0.0        1        0.0            1.0  0.45     0.0     0.0
# 13     3963.0        0     3963.0            1.0  1.00     1.0  6668.0
# ...       ...      ...        ...            ...   ...     ...     ...
# 21015    44.0        0       44.0            1.0  0.45     1.0  1457.0
# 21016     0.0        1        0.0            1.0  0.45     1.0  6405.0
# 21017     0.0        1        0.0            1.0  0.45     1.0   463.0
# 21018    14.0        0       14.0            1.0  0.45     1.0   564.0
# 21019     0.0        1        0.0            1.0  0.45     1.0  5024.0
#
#                AP  COOCDAT  Calif.modelo
# 9            0.00      NaN             4
# 10           0.00      NaN             4
# 11           0.00      NaN             4
# 12           0.00      NaN             0
# 13     3146429.00      NaN             2
# ...           ...      ...           ...
# 21015  2418121.00      NaN             1
# 21016  2020640.00      NaN             0
# 21017   775001.00      NaN             0
# 21018   945001.00      NaN             0
# 21019  1481471.88      NaN             0
#
# [13092 rows x 15 columns]

# %%
df_sin_libranza['Calif.modelo'] = df_sin_libranza['Calif.modelo'].map({0: 'A', 1: 'B', 2: 'C', 3:'D', 4:'E'})

# %%
condiciones = [
    (df_sin_libranza['Calif.modelo'] == 'A'),
    (df_sin_libranza['Calif.modelo'] == 'B') & (df_sin_libranza['MORA12'] <= 30),
    (df_sin_libranza['Calif.modelo'] == 'B') & (df_sin_libranza['MORA12'] > 30) & (df_sin_libranza['MORA12'] < 90),
    (df_sin_libranza['Calif.modelo'] == 'C') & (df_sin_libranza['MORA12'] <= 30),
    (df_sin_libranza['Calif.modelo'] == 'C') & (df_sin_libranza['MORA12'] > 30) & (df_sin_libranza['MORA12'] < 90),
    (df_sin_libranza['Calif.modelo'].isin(['D', 'E'])),
    (df_sin_libranza['MORA12'].between(90, 180))
]

opciones = ['A', 'A', 'B', 'B', 'C', 'C', 'D']

df_sin_libranza['Calif.homologada'] = np.select(condiciones, opciones, default='E')

# %%
df_sin_libranza['Calif.modelo'].value_counts()
# Out:
# Calif.modelo
# A    7642
# C    3867
# E     905
# B     657
# D      21
# Name: count, dtype: int64

# %%
df_sin_libranza['Calif.homologada'].value_counts()
# Out:
# Calif.homologada
# A    7642
# E    3076
# C    1243
# B     657
# D     474
# Name: count, dtype: int64

# %% [markdown]
# ## Calificación de arrastre, calificación final y cálculo de PI y PE

# %%
# Crear un dataframe que tenga una columna que seea el NIT de los dataframes df_con_libranza y df_sin_libranza y 
# otra columna que sea la peor calificacion homologada de cada NIT

df_peor_calificacion = pd.concat([df_con_libranza[['NIT', 'Calif.homologada']], df_sin_libranza[['NIT', 'Calif.homologada']]])
df_peor_calificacion = df_peor_calificacion.groupby('NIT')['Calif.homologada'].max().reset_index()
df_peor_calificacion
# Out:
#                  NIT Calif.homologada
# 0             204414                A
# 1             219552                A
# 2             366107                E
# 3             371497                A
# 4             398038                A
# ...              ...              ...
# 17966     9004400754                A
# 17967    10376145374                A
# 17968  811-012-598-6                A
# 17969  890-985-579-8                A
# 17970  900-937-066-2                E
#
# [17971 rows x 2 columns]

# %%
# En df_con_libranza crear una columna llamada 'Calif.final' cuyos valores sean iguales a la columna 'Calif.homologada' del df_peor_calificacion de acuerdo al valor de NIT.

df_con_libranza['Calif.final'] = df_con_libranza['NIT'].map(df_peor_calificacion.set_index('NIT')['Calif.homologada'])
df_con_libranza['Calif.final'].value_counts()
# Out:
# Calif.final
# A    7532
# B     134
# C      50
# E      37
# D      33
# Name: count, dtype: int64

# %%
# En df_sin_libranza crear una columna llamada 'Calif.final' cuyos valores sean iguales a la columna 'Calif.homologada' del df_peor_calificacion de acuerdo al valor de NIT.

df_sin_libranza['Calif.final'] = df_sin_libranza['NIT'].map(df_peor_calificacion.set_index('NIT')['Calif.homologada'])
df_sin_libranza['Calif.final'].value_counts()
# Out:
# Calif.final
# A    7514
# E    3105
# C    1277
# B     710
# D     486
# Name: count, dtype: int64

# %%
# Crear una columna llamada 'PI' aue se calcula así: si calificación es A, PI = 0.005; 
# si calificación es B, PI = 0.006; si calificación es C, PI = 0.0441; 
# si calificación es D, PI = 0.0448; si calificación es E, PI = 0.2273
df_con_libranza['PI'] = df_con_libranza['Calif.final'].map({
    'A': 0.005,
    'B': 0.006,
    'C': 0.0441,
    'D': 0.0448,
    'E': 0.2273
})

df_con_libranza['PI'] = df_con_libranza['PI'].astype(float)

df_con_libranza['PE'] = df_con_libranza['PI'] * df_con_libranza['VEA'] * df_con_libranza['PDI']

df_con_libranza
# Out:
#               NroCredito       NIT  CodigoContable   SALPRES         VEA  \
# 38     002-002-0096598-0  71648448        144105.0  0.030641    899571.0
# 44     002-002-0098148-1  98488766        144105.0  0.283385   9285591.0
# 49     002-002-0099325-4  98595907        144105.0  0.682244  52568339.0
# 106    002-002-0108169-2  43983251        144105.0  0.212897   2997504.0
# 118    002-002-0108733-9  71648785        141105.0  0.053903    960344.0
# ...                  ...       ...             ...       ...         ...
# 20638  006-002-0036302-9  86061031        144105.0  1.000000  33023529.0
# 20641  006-002-0036305-6  15431170        144105.0  1.000000   1653420.0
# 20644  006-002-0036312-7  71382018        144105.0  1.000000  10043347.0
# 20645  006-002-0036315-4  10126913        141105.0  1.000000   1425950.0
# 20649  006-002-0036333-2  15442864        144105.0  1.000000   1010370.0
#
#        MORA12  SINMORA  Morosidad  clasegarantia   PDI  Activo    ANTI  \
# 38        0.0        1        0.0            1.0  0.45     1.0  5445.0
# 44        0.0        1        0.0            1.0  0.45     1.0  5414.0
# 49       11.0        0       11.0            1.0  0.45     1.0  4837.0
# 106       0.0        1        0.0            1.0  0.45     1.0  6542.0
# 118       8.0        0        8.0            1.0  0.45     1.0  7699.0
# ...       ...      ...        ...            ...   ...     ...     ...
# 20638     0.0        1        0.0            1.0  0.45     1.0  5425.0
# 20641     0.0        1        0.0            1.0  0.45     1.0   516.0
# 20644     0.0        1        0.0            1.0  0.45     1.0  3202.0
# 20645     0.0        1        0.0            1.0  0.45     1.0  2201.0
# 20649     0.0        1        0.0            1.0  0.45     1.0   313.0
#
#                AP  COOCDAT Calif.modelo Calif.homologada Calif.final     PI  \
# 38      5844817.0      0.0            A                A           A  0.005
# 44      7105694.0      0.0            A                A           A  0.005
# 49     24388732.0      0.0            A                A           A  0.005
# 106     7448554.0      0.0            A                A           A  0.005
# 118    10945912.5      0.0            A                A           A  0.005
# ...           ...      ...          ...              ...         ...    ...
# 20638  11004175.0      0.0            A                A           A  0.005
# 20641    455907.0      0.0            A                A           A  0.005
# 20644   3545425.0      0.0            A                A           A  0.005
# 20645   1544370.0      0.0            A                A           A  0.005
# 20649    279001.0      0.0            A                A           A  0.005
#
#                  PE
# 38       2024.03475
# 44      20892.57975
# 49     118278.76275
# 106      6744.38400
# 118      2160.77400
# ...             ...
# 20638   74302.94025
# 20641    3720.19500
# 20644   22597.53075
# 20645    3208.38750
# 20649    2273.33250
#
# [7786 rows x 19 columns]

# %%
# Crear una columna llamada 'PI' aue se calcula así: si calificación es A, PI = 0.005; 
# si calificación es B, PI = 0.006; si calificación es C, PI = 0.0441; 
# si calificación es D, PI = 0.0448; si calificación es E, PI = 0.2273
df_sin_libranza['PI'] = df_sin_libranza['Calif.final'].map({
    'A': 0.015,
    'B': 0.0595,
    'C': 0.1382,
    'D': 0.3277,
    'E': 0.4171
})

df_sin_libranza['PI'] = df_sin_libranza['PI'].astype(float)

df_sin_libranza['PE'] = df_sin_libranza['PI'] * df_sin_libranza['VEA'] * df_sin_libranza['PDI']

df_sin_libranza
# Out:
#               NroCredito         NIT  CodigoContable   SALPRES         VEA  \
# 9      002-002-0013891-9    43801451        141210.0  0.264425   5345039.0
# 10     002-002-0048982-5    16224395        141225.0  0.310797  20012765.0
# 11     002-002-0054500-6    70130524        144225.0  0.912728  18820457.0
# 12     002-002-0063582-8    32523503        144205.0  0.044911    922145.0
# 13     002-002-0067978-1    71338874        144225.0  0.717959   7107791.0
# ...                  ...         ...             ...       ...         ...
# 21015  007-002-0001463-2  1035912774        144210.0  0.936706    980626.0
# 21016  007-002-0001464-1    15437544        144205.0  0.400000   4066557.0
# 21017  007-002-0001467-8    43907525        144205.0  0.880690   2684521.0
# 21018  007-002-0001468-7  1036964056        144205.0  0.940565   4851986.0
# 21019  007-002-0001472-1  1001370322        144205.0  0.623300   1871907.0
#
#        MORA12  SINMORA  Morosidad  clasegarantia   PDI  Activo    ANTI  \
# 9       217.0        0       53.0            3.0  0.50     0.0     0.0
# 10     3796.0        0     3796.0            1.0  1.00     0.0     0.0
# 11     3560.0        0     3560.0            1.0  1.00     0.0     0.0
# 12        0.0        1        0.0            1.0  0.45     0.0     0.0
# 13     3963.0        0     3963.0            1.0  1.00     1.0  6668.0
# ...       ...      ...        ...            ...   ...     ...     ...
# 21015    44.0        0       44.0            1.0  0.45     1.0  1457.0
# 21016     0.0        1        0.0            1.0  0.45     1.0  6405.0
# 21017     0.0        1        0.0            1.0  0.45     1.0   463.0
# 21018    14.0        0       14.0            1.0  0.45     1.0   564.0
# 21019     0.0        1        0.0            1.0  0.45     1.0  5024.0
#
#                AP  COOCDAT Calif.modelo Calif.homologada Calif.final      PI  \
# 9            0.00      NaN            E                C           C  0.1382
# 10           0.00      NaN            E                C           C  0.1382
# 11           0.00      NaN            E                C           C  0.1382
# 12           0.00      NaN            A                A           A  0.0150
# 13     3146429.00      NaN            C                E           E  0.4171
# ...           ...      ...          ...              ...         ...     ...
# 21015  2418121.00      NaN            B                B           B  0.0595
# 21016  2020640.00      NaN            A                A           A  0.0150
# 21017   775001.00      NaN            A                A           A  0.0150
# 21018   945001.00      NaN            A                A           A  0.0150
# 21019  1481471.88      NaN            A                A           A  0.0150
#
#                  PE
# 9      3.693422e+05
# 10     2.765764e+06
# 11     2.600987e+06
# 12     6.224479e+03
# 13     2.964660e+06
# ...             ...
# 21015  2.625626e+04
# 21016  2.744926e+04
# 21017  1.812052e+04
# 21018  3.275091e+04
# 21019  1.263537e+04
#
# [13092 rows x 19 columns]

# %% [markdown]
# ## Comparación sin libranza

# %%
pe_sin_libranza = pd.read_excel(
    'DETERIORO-SUPERSOLIDARIA_2025-09.xlsx',
    sheet_name='PE Consumo sin libranza',
)

pe_sin_libranza.head()
# Out:
#            N.Credito Calificacion TipoIden  NUMIDENT  CodigoContable  \
# 0  002-002-0176644-4            A        C  42791041        144205.0
# 1  002-002-0174537-9            A        C  42791041        144205.0
# 2  007-002-0000017-5            A        C  42791041        144205.0
# 3  004-002-0064765-3            A        C  71113904        144205.0
# 4  004-002-0071007-6            A        C  71113904        144205.0
#
#    SaldoCapital  SaldoIntereses  PagoxAsociados   APORTES  AHORROPERMANENTE  \
# 0      25000000         1812500               0  10734793               NaN
# 1      42448940         1358340               0  18227223               NaN
# 2       5493824           82620               0   2359003               NaN
# 3       4140217          619096               0    463407               NaN
# 4       4441560           26418               0    497136               NaN
#
#    ...  CALIFICACION    PI.1  CANTIDAD  %CANTIDAD         SALDO    %SALDO  \
# 0  ...             A  0.0150    7052.0   0.826439  1.018234e+11  0.777047
# 1  ...             B  0.0595     662.0   0.077581  8.520422e+09  0.065022
# 2  ...             C  0.1382     670.0   0.078519  1.937688e+10  0.147871
# 3  ...             D  0.3277      74.0   0.008672  5.628920e+08  0.004296
# 4  ...             E  0.4171      75.0   0.008789  7.553865e+08  0.005765
#
#            PE.1       %PE  %(PE/SALDO)     PROVISION
# 0  6.815585e+08  0.269324     0.006694  8.289143e+07
# 1  2.526353e+08  0.099831     0.029651  5.566278e+07
# 2  1.344109e+09  0.531137     0.069367  4.188014e+08
# 3  8.676750e+07  0.034287     0.154146  1.968502e+07
# 4  1.655551e+08  0.065421     0.219166  2.292156e+07
#
# [5 rows x 40 columns]

# %%
# Hacer dataframe que fusione la columna PE del dataframe pe_sin_libranza con el dataframe df_sin_libranza usando como clave primaria la columna NroCredito y N.Credito
comp_sin_libranza = pd.merge(
    pe_sin_libranza[['N.Credito', 'PE', 'Calificacion', 'PI', 'VEA', 'PDI']], 
    df_sin_libranza[['NroCredito', 'PE', 'Calif.final', 'PI', 'VEA', 'PDI']], 
    left_on='N.Credito', 
    right_on='NroCredito', 
    how='inner',
    suffixes=('_original', '_nuevo')
    )

comp_sin_libranza
# Out:
#               N.Credito   PE_original Calificacion  PI_original  VEA_original  \
# 0     002-002-0176644-4  180984.37500            A        0.015      26812500
# 1     002-002-0174537-9  295699.14000            A        0.015      43807280
# 2     007-002-0000017-5   37640.99700            A        0.015       5576444
# 3     004-002-0064765-3   32125.36275            A        0.015       4759313
# 4     004-002-0071007-6   30158.85150            A        0.015       4467978
# ...                 ...           ...          ...          ...           ...
# 8528  007-002-0001371-3    8071.06950            A        0.015       1195714
# 8529  007-002-0000638-4   15643.90800            A        0.015       2317616
# 8530  007-002-0001445-5   12897.18450            A        0.015       1910694
# 8531  007-002-0000597-3   14223.62700            A        0.015       2107204
# 8532  007-002-0000444-8   17416.03275            A        0.015       2580153
#
#       PDI_original         NroCredito      PE_nuevo Calif.final  PI_nuevo  \
# 0             0.45  002-002-0176644-4  180984.37500           A     0.015
# 1             0.45  002-002-0174537-9  295699.14000           A     0.015
# 2             0.45  007-002-0000017-5   37640.99700           A     0.015
# 3             0.45  004-002-0064765-3   32125.36275           A     0.015
# 4             0.45  004-002-0071007-6   30158.85150           A     0.015
# ...            ...                ...           ...         ...       ...
# 8528          0.45  007-002-0001371-3    8071.06950           A     0.015
# 8529          0.45  007-002-0000638-4   15643.90800           A     0.015
# 8530          0.45  007-002-0001445-5   12897.18450           A     0.015
# 8531          0.45  007-002-0000597-3   14223.62700           A     0.015
# 8532          0.45  007-002-0000444-8   17416.03275           A     0.015
#
#        VEA_nuevo  PDI_nuevo
# 0     26812500.0       0.45
# 1     43807280.0       0.45
# 2      5576444.0       0.45
# 3      4759313.0       0.45
# 4      4467978.0       0.45
# ...          ...        ...
# 8528   1195714.0       0.45
# 8529   2317616.0       0.45
# 8530   1910694.0       0.45
# 8531   2107204.0       0.45
# 8532   2580153.0       0.45
#
# [8533 rows x 12 columns]

# %%
pd.crosstab(comp_sin_libranza['Calificacion'], comp_sin_libranza['Calif.final'])
# Out:
# Calif.final      A    B    C    D   E
# Calificacion
# A             7039    0    2    4   7
# B               41  615    0    4   2
# C               23   89  317  186  55
# D                2    4   49    8  11
# E                2    0   73    0   0

# %%
pd.crosstab(comp_sin_libranza['PI_original'], comp_sin_libranza['PI_nuevo'])
# Out:
# PI_nuevo     0.0150  0.0595  0.1382  0.3277  0.4171
# PI_original
# 0.0150         7039       0       2       4       7
# 0.0595           41     615       0       4       2
# 0.1382           23      89     314     186      55
# 0.3277            2       4      49       8      11
# 0.4171            2       0      73       0       0
# 1.0000            0       0       3       0       0

# %%
pd.crosstab(comp_sin_libranza['PDI_original'], comp_sin_libranza['PDI_nuevo'])
# Out:
# PDI_nuevo     0.40  0.45  0.50  0.60
# PDI_original
# 0.40           129     0     0     0
# 0.45             0  7872     0     0
# 0.50             0     0    18     0
# 0.60             0   504     0    10

# %%
#comp_sin_libranza[comp_sin_libranza['PDI_original']==0.6]

# %%
comp_sin_libranza.plot(kind='scatter', x='PI_original', y='PI_nuevo')
plt.show();

# %%
comp_sin_libranza.plot(kind='scatter', x='PDI_original', y='PDI_nuevo')
plt.show();

# %%
comp_sin_libranza.plot(kind='scatter', x='VEA_original', y='VEA_nuevo')
plt.show();

# %%
comp_sin_libranza.plot(kind='scatter', x='PE_original', y='PE_nuevo')
plt.show();

# %%
comp_sin_libranza[['PE_original', 'PE_nuevo']].describe()
# Out:
#         PE_original      PE_nuevo
# count  8.533000e+03  8.533000e+03
# mean   2.965692e+05  3.290349e+05
# std    2.374830e+06  2.834552e+06
# min    1.991250e+00  1.991250e+00
# 25%    1.949685e+04  1.932757e+04
# 50%    5.480740e+04  5.358358e+04
# 75%    1.374913e+05  1.322292e+05
# max    1.567500e+08  1.018149e+08

# %%
maximo = comp_sin_libranza['PE_nuevo'].max()
print(maximo)
# Out:
# 101814893.85288

# %%
comp_sin_libranza[comp_sin_libranza['PE_nuevo']==maximo]
# Out:
#               N.Credito   PE_original Calificacion  PI_original  VEA_original  \
# 7835  002-002-0125184-7  4.293811e+07            C       0.1382     776738586
#
#       PDI_original         NroCredito      PE_nuevo Calif.final  PI_nuevo  \
# 7835           0.4  002-002-0125184-7  1.018149e+08           D    0.3277
#
#         VEA_nuevo  PDI_nuevo
# 7835  776738586.0        0.4

# %%
comp_sin_libranza[['PE_original', 'PE_nuevo']].sum()
# Out:
# PE_original    2.530625e+09
# PE_nuevo       2.807655e+09
# dtype: float64

# %% [markdown]
# ## Comparación con libranza

# %%
pe_con_libranza = pd.read_excel(
    'DETERIORO-SUPERSOLIDARIA_2025-09.xlsx',
    sheet_name='PE Consumo con libranza',
)

pe_con_libranza.head()
# Out:
#            N.Credito Calificacion TipoIden    NUMIDENT  CodigoContable  \
# 0  002-002-0118009-5            A        C  42791041.0        144105.0
# 1  002-002-0122632-2            A        C  42791041.0        144105.0
# 2  002-002-0139899-4            A        C  43063174.0        141105.0
# 3  002-002-0127351-0            D        C  42900158.0        144105.0
# 4  002-002-0176184-0            D        C  42900158.0        144105.0
#
#    SaldoCapital  SaldoIntereses  PagoxAsociados   APORTES  AHORROPERMANENTE  \
# 0      20070206            6690               0   8617980               NaN
# 1       6114330           17320               0   2625443               NaN
# 2     138738941          630356               0  39146709               NaN
# 3      19622287           16674               0  11406354               NaN
# 4      32911205          279514               0  19131147               NaN
#
#    ...  CALIFICACION    PI.1  CANTIDAD  %CANTIDAD         SALDO    %SALDO  \
# 0  ...             A  0.0050    7150.0   0.969623  6.090959e+10  0.959328
# 1  ...             B  0.0060     156.0   0.021155  1.845751e+09  0.029071
# 2  ...             C  0.0441      21.0   0.002848  3.383347e+08  0.005329
# 3  ...             D  0.0448      47.0   0.006374  3.982448e+08  0.006272
# 4  ...             E  0.0000       0.0   0.000000  0.000000e+00  0.000000
#
#            PE.1       %PE  %(PE/SALDO)    PROVISION
# 0  1.386038e+08  0.872921     0.002276  426952102.0
# 1  5.062941e+06  0.031886     0.002743    9438292.0
# 2  6.857174e+06  0.043186     0.020267   11791115.0
# 3  8.257701e+06  0.052007     0.020735    6797571.0
# 4  0.000000e+00  0.000000          NaN          0.0
#
# [5 rows x 40 columns]

# %%
pe_con_libranza.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7375 entries, 0 to 7374
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   N.Credito               7375 non-null   object
#  1   Calificacion            7374 non-null   object
#  2   TipoIden                7374 non-null   object
#  3   NUMIDENT                7374 non-null   float64
#  4   CodigoContable          7374 non-null   float64
#  5   SaldoCapital            7375 non-null   int64
#  6   SaldoIntereses          7375 non-null   int64
#  7   PagoxAsociados          7375 non-null   int64
#  8   APORTES                 7375 non-null   int64
#  9   AHORROPERMANENTE        1 non-null      float64
#  10  VEA                     7375 non-null   int64
#  11  VALORGARANTIA           7375 non-null   int64
#  12  TIPOGARANTIA            7374 non-null   float64
#  13  PORCGARANTIA            7374 non-null   float64
#  14  MODELO                  7374 non-null   float64
#  15  PI                      7374 non-null   float64
#  16  %Deterioro              0 non-null      float64
#  17  PDI                     7374 non-null   float64
#  18  PE                      7375 non-null   float64
#  19  DETERIOROCAPITAL        7374 non-null   float64
#  20  DETERIOROINTERESES      7374 non-null   float64
#  21  DETERIOROPAGOASOCIADOS  7374 non-null   float64
#  22  SALDOPENDIENTE          0 non-null      float64
#  23  PLAZOALICUOTA           0 non-null      float64
#  24  VALORALICUOTA           0 non-null      float64
#  25  DETERIOROACUM           0 non-null      float64
#  26  Provisión               7375 non-null   int64
#  27  Provisión intereses     7374 non-null   float64
#  28  CodOficina              7374 non-null   float64
#  29  Unnamed: 29             0 non-null      float64
#  30  CALIFICACION            6 non-null      object
#  31  PI.1                    6 non-null      float64
#  32  CANTIDAD                6 non-null      float64
#  33  %CANTIDAD               6 non-null      float64
#  34  SALDO                   6 non-null      float64
#  35  %SALDO                  6 non-null      float64
#  36  PE.1                    6 non-null      float64
#  37  %PE                     6 non-null      float64
#  38  %(PE/SALDO)             5 non-null      float64
#  39  PROVISION               6 non-null      float64
# dtypes: float64(29), int64(7), object(4)
# memory usage: 2.3+ MB

# %%
# Hacer dataframe que fusione la columna PE del dataframe pe_con_libranza con el dataframe df_con_libranza usando como clave primaria la columna NroCredito y N.Credito
comp_con_libranza = pd.merge(
    pe_con_libranza[['N.Credito', 'PE', 'Calificacion', 'PI', 'VEA', 'PDI']], 
    df_con_libranza[['NroCredito', 'PE', 'Calif.final', 'PI', 'VEA', 'PDI']], 
    left_on='N.Credito', 
    right_on='NroCredito', 
    how='inner',
    suffixes=('_original', '_nuevo')
    )

comp_con_libranza
# Out:
#               N.Credito   PE_original Calificacion  PI_original  VEA_original  \
# 0     002-002-0118009-5   45173.01600            A       0.0050      20076896
# 1     002-002-0122632-2   13796.21250            A       0.0050       6131650
# 2     002-002-0139899-4  348423.24250            A       0.0050     139369297
# 3     002-002-0127351-0  395921.45376            D       0.0448      19638961
# 4     002-002-0176184-0  669124.89504            D       0.0448      33190719
# ...                 ...           ...          ...          ...           ...
# 7365  002-002-0143587-3   23566.14000            A       0.0050      10473840
# 7366  002-002-0175621-3    1225.37250            A       0.0050        544610
# 7367  002-002-0177917-2    5268.05550            A       0.0050       2341358
# 7368  003-002-0131095-2     753.66000            A       0.0050        334960
# 7369  002-002-0139711-0    2425.88025            A       0.0050       1078169
#
#       PDI_original         NroCredito       PE_nuevo Calif.final  PI_nuevo  \
# 0             0.45  002-002-0118009-5   45173.016000           A    0.0050
# 1             0.45  002-002-0122632-2   13796.212500           A    0.0050
# 2             0.50  002-002-0139899-4  348423.242500           A    0.0050
# 3             0.45  002-002-0127351-0  389735.181045           C    0.0441
# 4             0.45  002-002-0176184-0  658669.818555           C    0.0441
# ...            ...                ...            ...         ...       ...
# 7365          0.45  002-002-0143587-3   23566.140000           A    0.0050
# 7366          0.45  002-002-0175621-3    1225.372500           A    0.0050
# 7367          0.45  002-002-0177917-2    5268.055500           A    0.0050
# 7368          0.45  003-002-0131095-2     753.660000           A    0.0050
# 7369          0.45  002-002-0139711-0    2425.880250           A    0.0050
#
#         VEA_nuevo  PDI_nuevo
# 0      20076896.0       0.45
# 1       6131650.0       0.45
# 2     139369297.0       0.50
# 3      19638961.0       0.45
# 4      33190719.0       0.45
# ...           ...        ...
# 7365   10473840.0       0.45
# 7366     544610.0       0.45
# 7367    2341358.0       0.45
# 7368     334960.0       0.45
# 7369    1078169.0       0.45
#
# [7370 rows x 12 columns]

# %%
pd.crosstab(comp_con_libranza['Calificacion'], comp_con_libranza['Calif.final'])
# Out:
# Calif.final      A    B   C  D   E
# Calificacion
# A             7115    0   0  5  26
# B               23  131   0  2   0
# C                0    1  16  4   0
# D                2    2  34  5   4

# %%
pd.crosstab(comp_con_libranza['PI_original'], comp_con_libranza['PI_nuevo'])
# Out:
# PI_nuevo     0.0050  0.0060  0.0441  0.0448  0.2273
# PI_original
# 0.0050         7115       0       0       5      26
# 0.0060           23     131       0       2       0
# 0.0441            0       1      16       4       0
# 0.0448            2       2      34       5       4

# %%
pd.crosstab(comp_con_libranza['PDI_original'], comp_con_libranza['PDI_nuevo'])
# Out:
# PDI_nuevo     0.40  0.45  0.50
# PDI_original
# 0.40             5     0     0
# 0.45             0  7360     0
# 0.50             0     0     5

# %%
comp_con_libranza.plot(kind='scatter', x='PE_original', y='PE_nuevo')
plt.show();

# %%
comp_con_libranza[['PE_original', 'PE_nuevo']].describe()
# Out:
#         PE_original      PE_nuevo
# count  7.370000e+03  7.370000e+03
# mean   2.153942e+04  2.906023e+04
# std    4.031212e+04  2.467670e+05
# min    2.750625e+01  2.750625e+01
# 25%    5.377366e+03  5.384762e+03
# 50%    1.211215e+04  1.216718e+04
# 75%    2.612865e+04  2.630064e+04
# max    1.214196e+06  1.766134e+07

# %%
comp_con_libranza[['PE_original', 'PE_nuevo']].sum()
# Out:
# PE_original    1.587455e+08
# PE_nuevo       2.141739e+08
# dtype: float64

# %%
maximo = comp_con_libranza['PE_nuevo'].max()
comp_con_libranza[comp_con_libranza['PE_nuevo']==maximo]
# Out:
#               N.Credito  PE_original Calificacion  PI_original  VEA_original  \
# 6188  002-002-0140327-4   388502.919            A        0.005     172667964
#
#       PDI_original         NroCredito      PE_nuevo Calif.final  PI_nuevo  \
# 6188          0.45  002-002-0140327-4  1.766134e+07           E    0.2273
#
#         VEA_nuevo  PDI_nuevo
# 6188  172667964.0       0.45
